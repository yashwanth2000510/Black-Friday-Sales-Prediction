# %% [markdown]
# # Black Friday Dataset EDA and Feature Engineering
#
# ### Cleaning and preparing the data for model train

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Problem Statement
# A retail company “ABC Private Limited” wants to understand the customer purchase behaviour (specifically, purchase amount) against various products of different categories. They have shared purchase summary of various customers for selected high volume products from last month. The data set also contains customer demographics (age, gender, marital status, city_type, stay_in_current_city), product details (product_id and product category) and Total purchase_amount from last month.
#
# Now, they want to build a model to predict the purchase amount of customer against various products which will help them to create personalized offer for customers against different products.

# %%
df_train = pd.read_csv('train.csv')
df_train.head()
# Out:
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN      8370
# 1                 6.0                14.0     15200
# 2                 NaN                 NaN      1422
# 3                14.0                 NaN      1057
# 4                 NaN                 NaN      7969

# %%
df_test = pd.read_csv("test.csv")
df_test.head()
# Out:
#    User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0  1000004  P00128942      M  46-50           7             B
# 1  1000009  P00113442      M  26-35          17             C
# 2  1000010  P00288442      F  36-45           1             B
# 3  1000010  P00145342      F  36-45           1             B
# 4  1000011  P00053842      F  26-35           1             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               1                   1
# 1                          0               0                   3
# 2                         4+               1                   5
# 3                         4+               1                   4
# 4                          1               0                   4
#
#    Product_Category_2  Product_Category_3
# 0                11.0                 NaN
# 1                 5.0                 NaN
# 2                14.0                 NaN
# 3                 9.0                 NaN
# 4                 5.0                12.0

# %% [markdown]
# ### Merging both train and test data

# %%
df = df_train.append(df_test)
df.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6136\3394615110.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df_train.append(df_test)
#    User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0  1000001  P00069042      F  0-17          10             A
# 1  1000001  P00248942      F  0-17          10             A
# 2  1000001  P00087842      F  0-17          10             A
# 3  1000001  P00085442      F  0-17          10             A
# 4  1000002  P00285442      M   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0
# 4                 NaN                 NaN    7969.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   User_ID                     783667 non-null  int64
#  1   Product_ID                  783667 non-null  object
#  2   Gender                      783667 non-null  object
#  3   Age                         783667 non-null  object
#  4   Occupation                  783667 non-null  int64
#  5   City_Category               783667 non-null  object
#  6   Stay_In_Current_City_Years  783667 non-null  object
#  7   Marital_Status              783667 non-null  int64
#  8   Product_Category_1          783667 non-null  int64
#  9   Product_Category_2          537685 non-null  float64
#  10  Product_Category_3          237858 non-null  float64
#  11  Purchase                    550068 non-null  float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 77.7+ MB

# %%
df.describe()
# Out:
#             User_ID     Occupation  Marital_Status  Product_Category_1  \
# count  7.836670e+05  783667.000000   783667.000000       783667.000000
# mean   1.003029e+06       8.079300        0.409777            5.366196
# std    1.727267e+03       6.522206        0.491793            3.878160
# min    1.000001e+06       0.000000        0.000000            1.000000
# 25%    1.001519e+06       2.000000        0.000000            1.000000
# 50%    1.003075e+06       7.000000        0.000000            5.000000
# 75%    1.004478e+06      14.000000        1.000000            8.000000
# max    1.006040e+06      20.000000        1.000000           20.000000
#
#        Product_Category_2  Product_Category_3       Purchase
# count       537685.000000       237858.000000  550068.000000
# mean             9.844506           12.668605    9263.968713
# std              5.089093            4.125510    5023.065394
# min              2.000000            3.000000      12.000000
# 25%              5.000000            9.000000    5823.000000
# 50%              9.000000           14.000000    8047.000000
# 75%             15.000000           16.000000   12054.000000
# max             18.000000           18.000000   23961.000000

# %%
df = df.drop(columns=['User_ID'])

# %% [markdown]
# ###  Handling the categorical feature Gender

# %%
df["Gender"] = df["Gender"].map({"F":0,"M":1})
df.head()
# Out:
#   Product_ID  Gender   Age  Occupation City_Category  \
# 0  P00069042       0  0-17          10             A
# 1  P00248942       0  0-17          10             A
# 2  P00087842       0  0-17          10             A
# 3  P00085442       0  0-17          10             A
# 4  P00285442       1   55+          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0
# 4                 NaN                 NaN    7969.0

# %% [markdown]
# ### Handling the categorical feature Age

# %%
df["Age"].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
df['Age'] = df['Age'].map({'0-17':1,'18-25':2,'26-35':3,'36-45':4,'46-50':5,'51-55':6,'55+':7})

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase
# 0                 NaN                 NaN    8370.0
# 1                 6.0                14.0   15200.0
# 2                 NaN                 NaN    1422.0
# 3                14.0                 NaN    1057.0
# 4                 NaN                 NaN    7969.0

# %% [markdown]
# ### Encoding the City_Category

# %%
df_city = pd.get_dummies(df['City_Category'])

# %%
df_city
# Out:
#         A  B  C
# 0       1  0  0
# 1       1  0  0
# 2       1  0  0
# 3       1  0  0
# 4       0  0  1
# ...    .. .. ..
# 233594  0  1  0
# 233595  0  1  0
# 233596  0  1  0
# 233597  0  0  1
# 233598  0  1  0
#
# [783667 rows x 3 columns]

# %%
df = pd.concat([df,df_city],axis =1)
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation City_Category  \
# 0  P00069042       0    1          10             A
# 1  P00248942       0    1          10             A
# 2  P00087842       0    1          10             A
# 3  P00085442       0    1          10             A
# 4  P00285442       1    7          16             C
#
#   Stay_In_Current_City_Years  Marital_Status  Product_Category_1  \
# 0                          2               0                   3
# 1                          2               0                   1
# 2                          2               0                  12
# 3                          2               0                  12
# 4                         4+               0                   8
#
#    Product_Category_2  Product_Category_3  Purchase  A  B  C
# 0                 NaN                 NaN    8370.0  1  0  0
# 1                 6.0                14.0   15200.0  1  0  0
# 2                 NaN                 NaN    1422.0  1  0  0
# 3                14.0                 NaN    1057.0  1  0  0
# 4                 NaN                 NaN    7969.0  0  0  1

# %%
df = df.drop(columns=['City_Category'])

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00069042       0    1          10                          2
# 1  P00248942       0    1          10                          2
# 2  P00087842       0    1          10                          2
# 3  P00085442       0    1          10                          2
# 4  P00285442       1    7          16                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 NaN                 NaN
# 1               0                   1                 6.0                14.0
# 2               0                  12                 NaN                 NaN
# 3               0                  12                14.0                 NaN
# 4               0                   8                 NaN                 NaN
#
#    Purchase  A  B  C
# 0    8370.0  1  0  0
# 1   15200.0  1  0  0
# 2    1422.0  1  0  0
# 3    1057.0  1  0  0
# 4    7969.0  0  0  1

# %% [markdown]
# ## Missing Values

# %%
df.isnull().sum()
# Out:
# Product_ID                         0
# Gender                             0
# Age                                0
# Occupation                         0
# Stay_In_Current_City_Years         0
# Marital_Status                     0
# Product_Category_1                 0
# Product_Category_2            245982
# Product_Category_3            545809
# Purchase                      233599
# A                                  0
# B                                  0
# C                                  0
# dtype: int64

# %% [markdown]
# ### Focus on replacing missing values

# %%
df["Product_Category_2"].unique()
# Out:
# array([nan,  6., 14.,  2.,  8., 15., 16., 11.,  5.,  3.,  4., 12.,  9.,
#        10., 17., 13.,  7., 18.])

# %%
df["Product_Category_2"].value_counts()
# Out:
# 8.0     91317
# 14.0    78834
# 2.0     70498
# 16.0    61687
# 15.0    54114
# 5.0     37165
# 4.0     36705
# 6.0     23575
# 11.0    20230
# 17.0    19104
# 13.0    15054
# 9.0      8177
# 12.0     7801
# 10.0     4420
# 3.0      4123
# 18.0     4027
# 7.0       854
# Name: Product_Category_2, dtype: int64

# %% [markdown]
# ### Replace the missing value with mode

# %%
df['Product_Category_2'].mode()[0]
# Out:
# 8.0

# %%
df['Product_Category_2']  = df['Product_Category_2'].fillna(df['Product_Category_2'].mode()[0])

# %%
df['Product_Category_2'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Product_Category_3 replacing values

# %%
df["Product_Category_3"].value_counts()
# Out:
# 16.0    46469
# 15.0    39968
# 14.0    26283
# 17.0    23818
# 5.0     23799
# 8.0     17861
# 9.0     16532
# 12.0    13115
# 13.0     7849
# 6.0      6888
# 18.0     6621
# 4.0      2691
# 11.0     2585
# 10.0     2501
# 3.0       878
# Name: Product_Category_3, dtype: int64

# %%
df['Product_Category_3'].mode()[0]
# Out:
# 16.0

# %%
df['Product_Category_3']  = df['Product_Category_3'].fillna(df['Product_Category_3'].mode()[0])

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00069042       0    1          10                          2
# 1  P00248942       0    1          10                          2
# 2  P00087842       0    1          10                          2
# 3  P00085442       0    1          10                          2
# 4  P00285442       1    7          16                         4+
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 8.0                16.0
# 1               0                   1                 6.0                14.0
# 2               0                  12                 8.0                16.0
# 3               0                  12                14.0                16.0
# 4               0                   8                 8.0                16.0
#
#    Purchase  A  B  C
# 0    8370.0  1  0  0
# 1   15200.0  1  0  0
# 2    1422.0  1  0  0
# 3    1057.0  1  0  0
# 4    7969.0  0  0  1

# %%
df.shape
# Out:
# (783667, 13)

# %%
df['Stay_In_Current_City_Years'].value_counts()
# Out:
# 1     276425
# 2     145427
# 3     135428
# 4+    120671
# 0     105716
# Name: Stay_In_Current_City_Years, dtype: int64

# %%
df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].str.replace('+','')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6136\66897005.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].str.replace('+','')

# %%
df.head()
# Out:
#   Product_ID  Gender  Age  Occupation Stay_In_Current_City_Years  \
# 0  P00069042       0    1          10                          2
# 1  P00248942       0    1          10                          2
# 2  P00087842       0    1          10                          2
# 3  P00085442       0    1          10                          2
# 4  P00285442       1    7          16                          4
#
#    Marital_Status  Product_Category_1  Product_Category_2  Product_Category_3  \
# 0               0                   3                 8.0                16.0
# 1               0                   1                 6.0                14.0
# 2               0                  12                 8.0                16.0
# 3               0                  12                14.0                16.0
# 4               0                   8                 8.0                16.0
#
#    Purchase  A  B  C
# 0    8370.0  1  0  0
# 1   15200.0  1  0  0
# 2    1422.0  1  0  0
# 3    1057.0  1  0  0
# 4    7969.0  0  0  1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      783667 non-null  int64
#  2   Age                         783667 non-null  int64
#  3   Occupation                  783667 non-null  int64
#  4   Stay_In_Current_City_Years  783667 non-null  object
#  5   Marital_Status              783667 non-null  int64
#  6   Product_Category_1          783667 non-null  int64
#  7   Product_Category_2          783667 non-null  float64
#  8   Product_Category_3          783667 non-null  float64
#  9   Purchase                    550068 non-null  float64
#  10  A                           783667 non-null  uint8
#  11  B                           783667 non-null  uint8
#  12  C                           783667 non-null  uint8
# dtypes: float64(3), int64(5), object(2), uint8(3)
# memory usage: 68.0+ MB

# %% [markdown]
# #### Converting object into integer

# %%
df['Stay_In_Current_City_Years'] = df['Stay_In_Current_City_Years'].astype('int64')

# %%
df['A'] = df['A'].astype('int64')
df['B'] = df['B'].astype('int64')
df['C'] = df['C'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 783667 entries, 0 to 233598
# Data columns (total 13 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Product_ID                  783667 non-null  object
#  1   Gender                      783667 non-null  int64
#  2   Age                         783667 non-null  int64
#  3   Occupation                  783667 non-null  int64
#  4   Stay_In_Current_City_Years  783667 non-null  int64
#  5   Marital_Status              783667 non-null  int64
#  6   Product_Category_1          783667 non-null  int64
#  7   Product_Category_2          783667 non-null  float64
#  8   Product_Category_3          783667 non-null  float64
#  9   Purchase                    550068 non-null  float64
#  10  A                           783667 non-null  int64
#  11  B                           783667 non-null  int64
#  12  C                           783667 non-null  int64
# dtypes: float64(3), int64(9), object(1)
# memory usage: 83.7+ MB

# %%
### Visualization 
sns.pairplot(df)

# %% [markdown]
# # Age vs Purchase

# %%
sns.barplot(x='Age',y='Purchase',hue='Gender',data=df)
# Out:
# <AxesSubplot: xlabel='Age', ylabel='Purchase'>

# %% [markdown]
# ## Purchasing of men is higher than women

# %% [markdown]
# ###  Purchase vs occupation

# %%
sns.barplot(x='Occupation',y='Purchase',hue='Gender',data=df)
# Out:
# <AxesSubplot: xlabel='Occupation', ylabel='Purchase'>

# %%
sns.barplot(x='Product_Category_1',y='Purchase',hue='Gender',data=df)
# Out:
# <AxesSubplot: xlabel='Product_Category_1', ylabel='Purchase'>

# %%
sns.barplot(x='Product_Category_2',y='Purchase',hue='Gender',data=df)
# Out:
# <AxesSubplot: xlabel='Product_Category_2', ylabel='Purchase'>

# %%
sns.barplot(x='Product_Category_3',y='Purchase',hue='Gender',data=df)
# Out:
# <AxesSubplot: xlabel='Product_Category_3', ylabel='Purchase'>

# %%
df.columns
# Out:
# Index(['Product_ID', 'Gender', 'Age', 'Occupation',
#        'Stay_In_Current_City_Years', 'Marital_Status', 'Product_Category_1',
#        'Product_Category_2', 'Product_Category_3', 'Purchase', 'A', 'B', 'C'],
#       dtype='object')

# %% [markdown]
# ## Feature Scaling

# %%
df_test = df[df['Purchase'].isnull()]

# %%
df_train = df[~df['Purchase'].isnull()]

# %%
X = df_train.drop(columns=['Purchase','Product_ID'],axis=1)
X.head()
# Out:
#    Gender  Age  Occupation  Stay_In_Current_City_Years  Marital_Status  \
# 0       0    1          10                           2               0
# 1       0    1          10                           2               0
# 2       0    1          10                           2               0
# 3       0    1          10                           2               0
# 4       1    7          16                           4               0
#
#    Product_Category_1  Product_Category_2  Product_Category_3  A  B  C
# 0                   3                 8.0                16.0  1  0  0
# 1                   1                 6.0                14.0  1  0  0
# 2                  12                 8.0                16.0  1  0  0
# 3                  12                14.0                16.0  1  0  0
# 4                   8                 8.0                16.0  0  0  1

# %%
y = df_train['Purchase']

# %%
X.shape
# Out:
# (550068, 11)

# %%
y.shape
# Out:
# (550068,)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Training Model

# %%
df.corr()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6136\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                               Gender       Age  Occupation  \
# Gender                      1.000000 -0.004758    0.116505
# Age                        -0.004758  1.000000    0.090882
# Occupation                  0.116505  0.090882    1.000000
# Stay_In_Current_City_Years  0.015026 -0.004968    0.028488
# Marital_Status             -0.010945  0.310747    0.023563
# Product_Category_1         -0.046208  0.060336   -0.008441
# Product_Category_2         -0.011851  0.041716    0.001501
# Product_Category_3         -0.006651  0.036721   -0.001576
# Purchase                    0.060346  0.015839    0.020833
# A                           0.006204 -0.096426   -0.023772
# B                          -0.005399 -0.016881   -0.011721
# C                          -0.000180  0.110302    0.035255
#
#                             Stay_In_Current_City_Years  Marital_Status  \
# Gender                                        0.015026       -0.010945
# Age                                          -0.004968        0.310747
# Occupation                                    0.028488        0.023563
# Stay_In_Current_City_Years                    1.000000       -0.012871
# Marital_Status                               -0.012871        1.000000
# Product_Category_1                           -0.003518        0.019579
# Product_Category_2                           -0.000081        0.012192
# Product_Category_3                           -0.000308        0.013808
# Purchase                                      0.005422       -0.000463
# A                                            -0.023769       -0.032790
# B                                             0.011011       -0.002804
# C                                             0.011007        0.034377
#
#                             Product_Category_1  Product_Category_2  \
# Gender                               -0.046208           -0.011851
# Age                                   0.060336            0.041716
# Occupation                           -0.008441            0.001501
# Stay_In_Current_City_Years           -0.003518           -0.000081
# Marital_Status                        0.019579            0.012192
# Product_Category_1                    1.000000            0.286502
# Product_Category_2                    0.286502            1.000000
# Product_Category_3                    0.319209            0.463528
# Purchase                             -0.343703           -0.128651
# A                                     0.017750            0.004857
# B                                    -0.003863           -0.003944
# C                                    -0.012870           -0.000443
#
#                             Product_Category_3  Purchase         A         B  \
# Gender                               -0.006651  0.060346  0.006204 -0.005399
# Age                                   0.036721  0.015839 -0.096426 -0.016881
# Occupation                           -0.001576  0.020833 -0.023772 -0.011721
# Stay_In_Current_City_Years           -0.000308  0.005422 -0.023769  0.011011
# Marital_Status                        0.013808 -0.000463 -0.032790 -0.002804
# Product_Category_1                    0.319209 -0.343703  0.017750 -0.003863
# Product_Category_2                    0.463528 -0.128651  0.004857 -0.003944
# Product_Category_3                    1.000000 -0.185945  0.016832  0.004291
# Purchase                             -0.185945  1.000000 -0.042465 -0.019098
# A                                     0.016832 -0.042465  1.000000 -0.516079
# B                                     0.004291 -0.019098 -0.516079  1.000000
# C                                    -0.020687  0.061012 -0.406769 -0.572552
#
#                                    C
# Gender                     -0.000180
# Age                         0.110302
# Occupation                  0.035255
# Stay_In_Current_City_Years  0.011007
# Marital_Status              0.034377
# Product_Category_1         -0.012870
# Product_Category_2         -0.000443
# Product_Category_3         -0.020687
# Purchase                    0.061012
# A                          -0.406769
# B                          -0.572552
# C                           1.000000

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
print("training score :",lr.score(X_train,y_train))
print("testing score :",lr.score(X_test,y_test))
print("R2 score :",r2_score(y_test,y_pred))
print("MSE :",mean_squared_error(y_test,y_pred))
# Out:
# training score : 0.13208547750135258
# testing score : 0.1292732288162055
# R2 score : 0.1292732288162055
# MSE : 21944295.706644807

# %%
d = DecisionTreeRegressor()
d.fit(X_train,y_train)
y_pred = d.predict(X_test)
print("training score :",d.score(X_train,y_train))
print("testing score :",d.score(X_test,y_test))
print("R2 score :",r2_score(y_test,y_pred))
print("MSE :",mean_squared_error(y_test,y_pred))
# Out:
# training score : 0.7962940670448273
# testing score : 0.559622948665194
# R2 score : 0.559622948665194
# MSE : 11098503.637108728

# %%
xgb = XGBRegressor()
xgb.fit(X_train,y_train)
y_pred = xgb.predict(X_test)
print("training score :",xgb.score(X_train,y_train))
print("testing score :",xgb.score(X_test,y_test))
print("R2 score :",r2_score(y_test,y_pred))
print("MSE :",mean_squared_error(y_test,y_pred))
# Out:
# training score : 0.6797080399005226
# testing score : 0.6670245351219605
# R2 score : 0.6670245351219605
# MSE : 8391739.298892956
